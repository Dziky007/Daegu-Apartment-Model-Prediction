# %% [markdown]
# # **Daegu Apartment**
#
# Dataset data_daegu_apartment.csv berisi informasi tentang apartemen di Daegu, Korea Selatan. Data ini mencakup berbagai atribut seperti jenis bangunan (terrace atau mixed), aksesibilitas ke fasilitas umum (seperti halte bus dan stasiun subway), jumlah fasilitas di sekitar dan di dalam kompleks apartemen, luas unit, harga jual, tahun pembangunan, dan lainnya.
#
# Dengan adanya berbagai parameter ini, muncul pertanyaan mengenai bagaimana faktor-faktor tersebut memengaruhi harga jual apartemen. Informasi ini penting bagi calon pembeli, investor properti, serta pengembang untuk menilai nilai pasar dan strategi investasi.
#
# Sebagai data scientist yang bergerak di bidang properti, maka saya tergerak untuk membuat suatu model prediktif melalui machine learning untuk memperkirakan harga apartemen di kota Daegu, Korea Selatan berdasarkan faktor-faktor yang tersedia dalam dataset data_daegu_apartment.csv secara akurat.

# %% [markdown]
# # **Outline**
#
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preprocessing
# 4. Modeling
# 5. Conclusion
# 6. Recommendation

# %% [markdown]
# # **Business Understanding**
#
# ## **Context**
#
# Daegu merupakan salahsatu kota terbesar di Korea Selatan  setelah Seoul, Busan, dan Incheon. Dengan lokasinya yang strategis, Daegu telah menjadi pusat perdagangan penting dengan sejarah panjang, yang membentang dari periode Baekje hingga dinasti Joseon . Daegu tidak hanya memiliki bentang alam yang kaya, tetapi cuacanya di Korea juga terkenal sejuk, sehingga sering menjadi pilihan untuk menyelenggarakan acara budaya, olahraga besar, dan destinasi wisata. Kota ini memiliki jumlah penduduk sebanyak 2,3 juta jiwa, sehingga Daegu dikenal dengan kota yang besar dengan jumlah penduduk yang cukup padat.
#
# Dengan padatnya jumlah penduduk di Daegu maka apartemen menjadi salah satu pilihan tempat tinggal ditengah kepadatan penduduk dan lahan yang terbatas.  Selain itu, Daegu juga memiliki banyak apartemen yang dibangun oleh pemerintah sebagai hunian untuk orang-orang yang berpenghasilan rendah. Oleh karena itu merupakan hal yang menarik untuk menganalisis harga apartemen berdasarkan faktor-faktor yang dapat mempengaruhinya.
#
# Individu atau perusahaan biasanya menawarkan unit apartemen untuk dijual. Penjual dapat memasang unit mereka di sebuah platform dengan menentukan harga jual sendiri. Cara ini cukup sulit bagi pemilik apartemen untuk menyesuaikan harganya dengan harga pasar. Jika harga terlalu tinggi dibandingkan harga pasar, maka akan sulit untuk melakukan penjualan. Sebaliknya, jika harganya terlalu rendah, pemilik akan kesulitan mendapatkan keuntungan maksimal. Oleh karena itu diperlukan adanya kesimbangan dalam penentuan harga agar harga yang ditetapkan sesuai dengan fasilitas yang disediakan sehingga pemilik dapat memaksimalkan keuntungan.

# %% [markdown]
# ## **Problem Statement**
# Individu atau perusahaan biasanya menawarkan unit apartemen untuk dijual. Penjual dapat memasang unit mereka di sebuah platform dengan menentukan harga jual sendiri. Cara ini cukup sulit bagi pemilik apartemen untuk menyesuaikan harganya dengan harga pasar. Jika harga terlalu tinggi dibandingkan harga pasar, maka akan sulit untuk melakukan penjualan. Sebaliknya, jika harganya terlalu rendah, pemilik akan kesulitan mendapatkan keuntungan maksimal. Oleh karena itu diperlukan adanya kesimbangan dalam penentuan harga agar harga yang ditetapkan sesuai dengan fasilitas yang disediakan sehingga pemilik dapat memaksimalkan keuntungan.
#
# Permasalahan utama dalam analisis ini yaitu terdapatnya kesulitan dalam menentukan harga jual apartemen yang ideal dengan mempertimbangkan fitur dan fasilitas yang tersedia. Maka solusi dari permasalahan ini yaitu diperlukan adanya suatu model predksi harga yang akurat guna membantu penentuan harga jual apartemen.

# %% [markdown]
# ## **Goals**
#
# Berdasarkan masalah yang telah diuraikan, maka tujuan utama dari analisis ini adalah membangun model prediksi harga jual apartemen berdasarkan fitur-fitur yang tersedia dalam dataset. Adanya perbedaan fitur yand terdapat pada setiap apartment akan menambah keakuratan harga jual yang dapat menguntungkan penjual.Hasil dari prediksi tersebut akan Memberikan rekomendasi berbasis data untuk pihak-pihak terkait, seperti investor atau pembeli rumah, terkait faktor-faktor kunci yang memengaruhi nilai properti.

# %% [markdown]
# ## **Analytic Approach**
# Langkah pertama yang perlu dilakukan adalah menganalisis data untuk mengidentifikasi pola dari berbagai fitur yang membedakan satu apartemen dengan lainnya. Analisis ini bertujuan untuk memahami hubungan antara karakteristik apartemen dengan harga jualnya.
# Selanjutnya, merancang dan membangun model regresi yang berfungsi sebagai alat prediksi rekomendasi harga jual unit yang lebih akurat dan mendukung pemilik atau agen properti dalam menetapkan harga jual yang kompetitif di pasar.

# %% [markdown]
# ## **Metric Evaluation**
# Metode evaluasi yang digunakan untuk model regresi mencakup RMSE, MAE, dan MAPE.
#
# 1. RMSE (Root Mean Squared Error) mengukur akar kuadrat dari rata-rata kesalahan prediksi.
#
# 2. MAE (Mean Absolute Error) menghitung rata-rata nilai absolut dari kesalahan prediksi.
#
# 3. MAPE (Mean Absolute Percentage Error) menunjukkan rata-rata persentase kesalahan prediksi. Semakin kecil nilai RMSE, MAE, dan MAPE, semakin baik model tersebut dalam memprediksi harga apartemen berdasarkan fitur yang digunakan.
#
# 4. Selain itu, metrik R-Squared (R2) juga dapat digunakan. R-Squared (koefisien determinasi) mengukur sejauh mana variabilitas data dapat dijelaskan oleh model, dengan nilai berkisar antara 0 hingga 1. Nilai yang mendekati 1 menunjukkan bahwa model mampu merepresentasikan data dengan baik. Namun, R-Squared hanya relevan untuk model linear, sehingga tidak dapat digunakan untuk mengevaluasi model non-linear.
#
# Penggunaan kombinasi metrik ini memberikan gambaran yang lebih komprehensif tentang performa model dan memastikan akurasi dalam memprediksi harga apartemen.

# %% [markdown]
# ## **Features Explanation**
#
# - Hallway Type : Tipe apartemen
# - TimeToSUbway : Waktu yang diperlukan untuk sampai ke statsiun kereta terdekat
# - SubwayStation: Nama stasiun kereta terdekat
# - N_FacilitiesNearBy(ETC): Jumlah fasilitas terdekat
# - N_FacilitiesNearBy(PublicOffice): Jumlah perkantoran terdekat
# - N_SchoolNearBy(University): Jumlah universitas terdekat
# - N_Parkinglot(Basement): Jumlah tempat parkir
# - YearBuilt: Tahun apartemen dibangun
# - N_FacilitiesInApt: Jumlah fasilitas yang terdapat di apartemen
# - Size(sqft): Ukuran apartemen
# - SalePrice: Harga apartemen

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# split
from sklearn.model_selection import train_test_split

# column transformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Preprocessing
# imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer,IterativeImputer, KNNImputer

# encoding
from sklearn.preprocessing import OneHotEncoder
from category_encoders import OrdinalEncoder
from category_encoders.binary import BinaryEncoder

# scaling
from sklearn.preprocessing import StandardScaler, RobustScaler

# Cross Validation
from sklearn.model_selection import StratifiedKFold, KFold,cross_val_score, cross_validate
from sklearn.compose import TransformedTargetRegressor

# model Regression
from sklearn.tree import plot_tree, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor


# Hyperparameter Tuning
from sklearn.model_selection import RandomizedSearchCV

# scoring regression
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score, mean_squared_error

# %% [markdown]
# # **Data Understanding**

# %%
# Load Dataset
df = pd.read_csv('data_daegu_apartment.csv')
df.head()
# Out:
#   HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0    terraced       0-5min  Kyungbuk_uni_hospital                      0.0
# 1    terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 2       mixed  15min~20min       Chil-sung-market                      1.0
# 3       mixed   5min~10min                Bangoge                      5.0
# 4    terraced       0-5min                Sin-nam                      0.0
#
#    N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 0                               3.0                         2.0
# 1                               5.0                         1.0
# 2                               7.0                         3.0
# 3                               5.0                         4.0
# 4                               1.0                         2.0
#
#    N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4123 entries, 0 to 4122
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HallwayType                       4123 non-null   object
#  1   TimeToSubway                      4123 non-null   object
#  2   SubwayStation                     4123 non-null   object
#  3   N_FacilitiesNearBy(ETC)           4123 non-null   float64
#  4   N_FacilitiesNearBy(PublicOffice)  4123 non-null   float64
#  5   N_SchoolNearBy(University)        4123 non-null   float64
#  6   N_Parkinglot(Basement)            4123 non-null   float64
#  7   YearBuilt                         4123 non-null   int64
#  8   N_FacilitiesInApt                 4123 non-null   int64
#  9   Size(sqf)                         4123 non-null   int64
#  10  SalePrice                         4123 non-null   int64
# dtypes: float64(4), int64(4), object(3)
# ...

# %% [markdown]
# Menampilkan informasi mengenai tipe data, nilai null, dan data unik dari setiap kolom

# %%
df_desc = []

for i in df.columns:
    df_desc.append([i,
                    df[i].dtypes,
                    df[i].isna().sum(),
                    round((df[i].isna().sum()/len(df)*100),2),
                    df[i].nunique(),
                    df[i].unique()])

df_deepInfo = pd.DataFrame(df_desc, columns = ['columns', 'data_type', 'null', 'null%', 'unique','sample'])
print(len(df_deepInfo.values))
print(f"Amount of Data: {len(df)}")
df_deepInfo
# Out:
# 11
# Amount of Data: 4123
#                              columns data_type  null  null%  unique  \
# 0                        HallwayType    object     0    0.0       3
# 1                       TimeToSubway    object     0    0.0       5
# 2                      SubwayStation    object     0    0.0       8
# 3            N_FacilitiesNearBy(ETC)   float64     0    0.0       4
# 4   N_FacilitiesNearBy(PublicOffice)   float64     0    0.0       8
# 5         N_SchoolNearBy(University)   float64     0    0.0       6
# 6             N_Parkinglot(Basement)   float64     0    0.0      20
# 7                          YearBuilt     int64     0    0.0      16
# 8                  N_FacilitiesInApt     int64     0    0.0       9
# 9                          Size(sqf)     int64     0    0.0      89
# 10                         SalePrice     int64     0    0.0     838
#
#                                                sample
# 0                         [terraced, mixed, corridor]
# ...

# %% [markdown]
# Berdasarkan data diatas diperoleh informasi bahwa tidak terdapat missing value dalam dataset ini. Namun, terdapat nilai/angka 0 pada kolom N_FacilitesNearBy(ETC), N_FacilitiesNearBy(PublicOffice), N_SchoolNearBy(University), dan N_Parkinglot(Basement). Maka kita perlu mengecek apakah nilai tersebut merupakan missing value atau bukan.

# %%
df[df['N_FacilitiesNearBy(ETC)'] == 0]
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0       terraced       0-5min  Kyungbuk_uni_hospital                      0.0
# 4       terraced       0-5min                Sin-nam                      0.0
# 6       terraced       0-5min             Banwoldang                      0.0
# 9       corridor   5min~10min             Banwoldang                      0.0
# 15      terraced       0-5min  Kyungbuk_uni_hospital                      0.0
# ...          ...          ...                    ...                      ...
# 4112    corridor   5min~10min             Banwoldang                      0.0
# 4113    terraced   5min~10min                  Daegu                      0.0
# 4116    terraced       0-5min                Sin-nam                      0.0
# 4118    terraced       0-5min                Sin-nam                      0.0
# 4122    terraced       0-5min  Kyungbuk_uni_hospital                      0.0
#
# ...

# %%
df[df['N_FacilitiesNearBy(PublicOffice)'] == 0]
# Out:
#      HallwayType TimeToSubway SubwayStation  N_FacilitiesNearBy(ETC)  \
# 26      terraced       0-5min    Banwoldang                      0.0
# 56      terraced       0-5min    Banwoldang                      0.0
# 114     terraced       0-5min    Banwoldang                      0.0
# 316     terraced       0-5min    Banwoldang                      0.0
# 337     terraced       0-5min    Banwoldang                      0.0
# 390     terraced       0-5min    Banwoldang                      0.0
# 436     terraced       0-5min    Banwoldang                      0.0
# 443     terraced       0-5min    Banwoldang                      0.0
# 545     terraced       0-5min    Banwoldang                      0.0
# 566     terraced       0-5min    Banwoldang                      0.0
# 693     terraced       0-5min    Banwoldang                      0.0
# 726     terraced       0-5min    Banwoldang                      0.0
# 895     terraced       0-5min    Banwoldang                      0.0
# ...

# %%
df[df['N_SchoolNearBy(University)'] == 0]
# Out:
#      HallwayType TimeToSubway SubwayStation  N_FacilitiesNearBy(ETC)  \
# 26      terraced       0-5min    Banwoldang                      0.0
# 50      corridor   5min~10min         Daegu                      2.0
# 56      terraced       0-5min    Banwoldang                      0.0
# 114     terraced       0-5min    Banwoldang                      0.0
# 118     corridor   5min~10min         Daegu                      2.0
# ...          ...          ...           ...                      ...
# 3807    corridor   5min~10min         Daegu                      2.0
# 3857    terraced       0-5min    Banwoldang                      0.0
# 4001    corridor   5min~10min         Daegu                      2.0
# 4035    terraced       0-5min    Banwoldang                      0.0
# 4121    corridor   5min~10min         Daegu                      2.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 26                                 0.0                         0.0
# ...

# %%
df[df['N_Parkinglot(Basement)'] == 0]
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 1       terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 10      terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 45      corridor       0-5min  Kyungbuk_uni_hospital                      0.0
# 53      corridor  10min~15min              Myung-duk                      5.0
# 64      corridor  10min~15min              Myung-duk                      5.0
# ...          ...          ...                    ...                      ...
# 4086    corridor  10min~15min              Myung-duk                      5.0
# 4099    terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 4100    terraced  10min~15min  Kyungbuk_uni_hospital                      1.0
# 4109    corridor  10min~15min              Myung-duk                      5.0
# 4114    corridor  10min~15min              Myung-duk                      5.0
#
# ...

# %% [markdown]
# Setelah dilakukan pemeriksaan, diperoleh informasi bahwa nilai 0 pada dataset ini bukan merupakan missing value. Nilai 0 pada dataset ini dapat diartikan bahwa tidak terdapatnya fasilitas/ketidaktersediaan fasilitas apartemen.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
df.describe()
# Out:
#        N_FacilitiesNearBy(ETC)  N_FacilitiesNearBy(PublicOffice)  \
# count              4123.000000                       4123.000000
# mean                  1.930876                          4.135338
# std                   2.198832                          1.802640
# min                   0.000000                          0.000000
# 25%                   0.000000                          3.000000
# 50%                   1.000000                          5.000000
# 75%                   5.000000                          5.000000
# max                   5.000000                          7.000000
#
#        N_SchoolNearBy(University)  N_Parkinglot(Basement)    YearBuilt  \
# count                 4123.000000             4123.000000  4123.000000
# mean                     2.746301              568.979141  2002.999757
# std                      1.496610              410.372742     8.905768
# min                      0.000000                0.000000  1978.000000
# ...

# %% [markdown]
# Dapat diketahui bahwa harga terrendah apartment berada pada angka 32743, dan harga tertinggi apartment berada pada angka 585840

# %%
# Menampilkan apartmen yang memiliki harga terrendah
df[df['SalePrice'] == df['SalePrice'].min()]
# Out:
#      HallwayType TimeToSubway SubwayStation  N_FacilitiesNearBy(ETC)  \
# 1908    corridor  10min~15min     Myung-duk                      5.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 1908                               7.0                         5.0
#
#       N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  \
# 1908                     0.0       1992                  3        355
#
#       SalePrice
# 1908      32743

# %%
# Menampilkan apartmen yang memiliki harga tertinggi
df[df['SalePrice'] == df['SalePrice'].max()]
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 2128    terraced       0-5min  Kyungbuk_uni_hospital                      0.0
#
#       N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# 2128                               3.0                         2.0
#
#       N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  Size(sqf)  \
# 2128                  1270.0       2007                 10       1928
#
#       SalePrice
# 2128     585840

# %%
# Grouping tipe properti berdasarkan neighbourhood group
df.groupby('HallwayType').size().reset_index(name='count').sort_values(by='count', ascending=False)
# Out:
#   HallwayType  count
# 2    terraced   2528
# 1       mixed   1131
# 0    corridor    464

# %%
ax1 = sns.countplot(x='HallwayType', data=df, order=df['HallwayType'].value_counts().index,hue='HallwayType')
for container in ax1.containers:
    for bar in container:
        height = bar.get_height()
        ax1.text(
            bar.get_x() + bar.get_width() / 2,
            height + 0.1,
            f'{height:.0f}',
            ha='center',
            va='bottom'
        )

plt.title('Count of HallwayType')        
plt.xlabel('HallwayType')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Hallwaytype apartment di Daegu di dominasi oleh tipe terraced.

# %%
# Cek median price untuk tiap HallwayType
df_median_price = df.groupby(by=['HallwayType']).agg({'SalePrice':'median'}).reset_index()
df_median_price = df_median_price.set_index('HallwayType')
df_median_price = df_median_price.sort_values('SalePrice', ascending =False)
df_median_price
# Out:
#              SalePrice
# HallwayType
# terraced      264601.0
# mixed         153539.0
# corridor       74557.0

# %%
ax2 = sns.barplot(x = df_median_price.index, y = df_median_price['SalePrice'], hue= df_median_price.index)
for container in ax2.containers:
    for bar in container:
        height = bar.get_height()
        ax2.text(
            bar.get_x() + bar.get_width() / 2,
            height + 0.1,
            f'{height:.0f}',
            ha='center',
            va='bottom'
        )

plt.title('Median Price by HallwayType')
plt.show()

# %%
# Cek median price untuk tiap TimeToSubway
tts_median_price = df.groupby(by=['TimeToSubway']).agg({'SalePrice':'median'}).reset_index()
tts_median_price = tts_median_price.set_index('TimeToSubway')
tts_median_price = tts_median_price.sort_values('SalePrice', ascending =False)
tts_median_price
# Out:
#                     SalePrice
# TimeToSubway
# 0-5min               279646.0
# no_bus_stop_nearby   203646.0
# 10min~15min          159292.0
# 5min~10min           153539.0
# 15min~20min          138938.0

# %%
ax3 = sns.barplot(x=tts_median_price.index, y=tts_median_price['SalePrice'],hue= tts_median_price.index)
for container in ax3.containers:
    for bar in container:
        height = bar.get_height()
        ax3.text(
            bar.get_x() + bar.get_width() / 2,
            height + 0.1,
            f'{height:.0f}',
            ha='center',
            va='bottom'
        )

plt.title('Median Price by TimeToSubway')
plt.xlabel('TimeToSubway')
plt.ylabel('Median SalePrice')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Berdasarkan grafik ditas dapat diketahui bahwa semakin dekat jarak apartment dengan Subway maka media harga apartment pun akan semakin tinggi, namun hal yang menarik terjadi pada median harga apartment yang waktu ke stasiun keretanya 5-10 menit justru lebih rendah daripada apartment yang waktu ke stasiun keretanya 10-15 menit. Hal ini dapat disebabkan oleh faktor lain seperti fasilitas yang tersedia di sekitar dan di dalam apartment tersebut.

# %%
pivot = df.pivot_table(index='SubwayStation', columns='HallwayType', values='SalePrice', aggfunc='median')
pivot
# Out:
# HallwayType            corridor     mixed  terraced
# SubwayStation
# Bangoge                     NaN  167035.0       NaN
# Banwoldang             101769.0       NaN  337168.0
# Chil-sung-market            NaN   88495.0       NaN
# Daegu                   70796.0       NaN  300884.0
# Kyungbuk_uni_hospital  163716.0       NaN  244911.0
# Myung-duk               65486.0  149557.0  271681.0
# Sin-nam                 87610.0       NaN  256637.0
# no_subway_nearby        58407.0       NaN  243362.0

# %%
pivot = df.groupby(['SubwayStation', 'HallwayType'])['SalePrice'].median().unstack()
pivot_reset = pivot.reset_index().melt(id_vars='SubwayStation', var_name='HallwayType', value_name='SalePrice')

subway_totals = pivot_reset.groupby('SubwayStation')['SalePrice'].sum().reset_index(name='TotalSalePrice')

# Merge the TotalSalePrice back into pivot_reset
pivot_reset = pivot_reset.merge(subway_totals, on='SubwayStation', how='left')

sorted_subways = subway_totals.sort_values('TotalSalePrice', ascending=False)['SubwayStation']

pivot_pivoted = pivot_reset.pivot(index='SubwayStation', columns='HallwayType', values='SalePrice')

pivot_pivoted = pivot_pivoted.reindex(sorted_subways)

pivot_pivoted.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xticks(rotation=90)
plt.title('Median SalePrice by SubwayStation and HallwayType')
plt.ylabel('SalePrice')
plt.xlabel('SubwayStation')
plt.legend(title='HallwayType')
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafik tersebut secara tidak langsung dapat menginterpretasikan dimana apartment tersebut dibangun, meskipun tidak disertakan dengan jelas dalam dataset. Namun kita dapat memprediksi bahwa daerah yang dekat dengan stasiun kereta Myungduk cenderung memiliki median harga yang tinggi dibandingkan dengan wilayah yang dekat dengan stasiun kereta lainnya.

# %%
sns.histplot(df['SalePrice'], bins=50, kde=True)
plt.title('Distribution of SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Berdasarkan data dari histplot diatas, terlihat adanya distribusi data yang condong ke kanan atau *rightskew* yang mana kolom SalePrice memiliki skewness positif. Hal ini berarti bahwa sebagian besar data harga bernilai rendah dan beberapa nilai harga tinggi menarik distribusi data ke arah kanan.

# %%
df['SubwayStation'].unique()
# Out:
# array(['Kyungbuk_uni_hospital', 'Chil-sung-market', 'Bangoge', 'Sin-nam',
#        'Banwoldang', 'no_subway_nearby', 'Myung-duk', 'Daegu'],
#       dtype=object)

# %%
sns.scatterplot(x='Size(sqf)', y='SalePrice', data=df)
plt.title('Scatterplot of SalePrice vs Size(sqf)')
plt.show()

# %% [markdown]
# Data diatas menunjukkan kecenderungan semakin luas ukuran apartment maka semakin tinggi pula harganya. Untuk memperjelas korelasinya maka akan ditampilkan dalam bentuk heatmap.

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix and plot the heatmap
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# Analis menemukan ketidakkosistenan data pada kolom TimeToSubway dan SubwayStation. Hal ini perlu dilakukan penanganan agar model prediksi tidak terganggu.

# %%
# Mengganti karakter '~' dengan '-' pada kolom 'TimeToSubway'
df['TimeToSubway'] = df['TimeToSubway'].str.replace('~', '-')

# Mengganti karakter '-' dengan '_' pada kolom 'SubwayStation'
df['SubwayStation'] = df['SubwayStation'].str.replace('-', '_')

# %% [markdown]
# Kemudian analis menemukan bahwa kolom 'N_FacilitiesNearBy(ETC), N_FacilitiesNearBy(PublicOffice), N_SchoolNearBy(University), dan N_Parkinglot(Basement) bertipe float/desimal. Analis akan merubahnya ke dalam tipe integer, karena tidak mungkin jika jumlah fasilitas terdekat sebanyak 2.5.

# %%
# Merubah tipe data dari float menjadi int
df['N_FacilitiesNearBy(ETC)'] = df['N_FacilitiesNearBy(ETC)'].astype('int64')
df['N_FacilitiesNearBy(PublicOffice)'] = df['N_FacilitiesNearBy(PublicOffice)'].astype('int64')
df['N_SchoolNearBy(University)'] = df['N_SchoolNearBy(University)'].astype('int64')
df['N_Parkinglot(Basement)'] = df['N_Parkinglot(Basement)'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4123 entries, 0 to 4122
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HallwayType                       4123 non-null   object
#  1   TimeToSubway                      4123 non-null   object
#  2   SubwayStation                     4123 non-null   object
#  3   N_FacilitiesNearBy(ETC)           4123 non-null   int64
#  4   N_FacilitiesNearBy(PublicOffice)  4123 non-null   int64
#  5   N_SchoolNearBy(University)        4123 non-null   int64
#  6   N_Parkinglot(Basement)            4123 non-null   int64
#  7   YearBuilt                         4123 non-null   int64
#  8   N_FacilitiesInApt                 4123 non-null   int64
#  9   Size(sqf)                         4123 non-null   int64
#  10  SalePrice                         4123 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 354.4+ KB

# %%
# Memeriksa apakah ada data yang duplikat
duplikat = df.duplicated().sum() / len(df) * 100
print(f'jumlah data duplikat pada data ini sebanyak {duplikat} atau {round(duplikat, 2)}% dari total data')
# Out:
# jumlah data duplikat pada data ini sebanyak 34.48944943002668 atau 34.49% dari total data

# %%
df.shape
# Out:
# (4123, 11)

# %%
# Data dupilikat pada dataset ini lebih baik dihapus agar hasil analisis tidak menjadi bias
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2701, 11)

# %% [markdown]
# Setelah dilakukan penghapusan duplikasi maka data ini berjumlah 2701 baris dan 11 kolom

# %%
#  Menggunakan boxplot untuk mencari outliers
numerikal_features = df.describe().columns

for data in numerikal_features:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=df[data])
    plt.title(f'Distribusi: {data}')
    plt.xlabel(data)


plt.tight_layout()
plt.show()

# %%
# Memeriksa persentase oulier pada masing-masing kolom
outlier_percentage = {}
for column in numerikal_features:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1

    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR

# Hitung jumlah outlier
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    num_outliers = outliers.shape[0]

# Menghitung persentase outlier
    total_data = df.shape[0]
    percentage_outliers = (num_outliers/total_data)*100
    outlier_percentage[column] = percentage_outliers

outlier_df = pd.DataFrame.from_dict(outlier_percentage, orient='index', columns=['Outlier Percentage'])
print(outlier_df)
# Out:
#                                   Outlier Percentage
# N_FacilitiesNearBy(ETC)                     0.000000
# N_FacilitiesNearBy(PublicOffice)            0.000000
# N_SchoolNearBy(University)                  0.000000
# N_Parkinglot(Basement)                      0.000000
# YearBuilt                                   0.000000
# N_FacilitiesInApt                           0.000000
# Size(sqf)                                   3.109959
# SalePrice                                   0.629397

# %% [markdown]
# Terdapat outlier pada kolom Size(sqf) dan SalePrice dengan presentase outlier sebesar 3,1% dan 0.62%

# %%
def outlier(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    lower_bound = q1 - limit
    upper_bound = q3 + limit
    print(f'lower_bound: {lower_bound}')
    print(f'upper_bound: {upper_bound}')

# %% [markdown]
# Untuk mengurangi skewness data maka analis menghapus data outlier yang terlalu extreme, namun untuk outlier yang tidak terlalu extreme tetap dipertahankan karena data tersebut masih relevan.

# %% [markdown]
# ## Menghapus Data Outlier Extreme Pada Kolom Size(sqf)

# %%
outlier(df['Size(sqf)'])
# Out:
# IQR: 424.0
# lower_bound: 107.0
# upper_bound: 1803.0

# %%
df['Size(sqf)'].describe()
# Out:
# count    2701.000000
# mean      984.028878
# std       391.982619
# min       135.000000
# 25%       743.000000
# 50%       910.000000
# 75%      1167.000000
# max      2337.000000
# Name: Size(sqf), dtype: float64

# %%
df[df['Size(sqf)']>1803].count()['Size(sqf)']
# Out:
# np.int64(84)

# %%
df[df['Size(sqf)'] > 1803].groupby('Size(sqf)').count()
# Out:
#            HallwayType  TimeToSubway  SubwayStation  N_FacilitiesNearBy(ETC)  \
# Size(sqf)
# 1928                29            29             29                       29
# 2056                23            23             23                       23
# 2092                 8             8              8                        8
# 2337                24            24             24                       24
#
#            N_FacilitiesNearBy(PublicOffice)  N_SchoolNearBy(University)  \
# Size(sqf)
# 1928                                     29                          29
# 2056                                     23                          23
# 2092                                      8                           8
# 2337                                     24                          24
#
#            N_Parkinglot(Basement)  YearBuilt  N_FacilitiesInApt  SalePrice
# Size(sqf)
# 1928                           29         29                 29         29
# ...

# %%
df=df[df['Size(sqf)'] <= 2056]
sns.histplot(df['Size(sqf)'], bins=50, kde=True)
plt.show()

# %% [markdown]
# ## Menghapus Data Outlier Extreme Pada Kolom SalePrice

# %%
outlier(df['SalePrice'])
# Out:
# IQR: 148672.0
# lower_bound: -70796.0
# upper_bound: 523892.0

# %%
df['SalePrice'].describe()
# Out:
# count      2669.000000
# mean     229221.718247
# std      105488.385677
# min       32743.000000
# 25%      152212.000000
# 50%      220353.000000
# 75%      300884.000000
# max      585840.000000
# Name: SalePrice, dtype: float64

# %%
df[df['SalePrice']>521901].count()['SalePrice']
# Out:
# np.int64(17)

# %%
df[df['SalePrice'] > 521901].groupby('SalePrice').count()
# Out:
#            HallwayType  TimeToSubway  SubwayStation  N_FacilitiesNearBy(ETC)  \
# SalePrice
# 522123               1             1              1                        1
# 526548               3             3              3                        3
# 527433               1             1              1                        1
# 528318               1             1              1                        1
# 529203               2             2              2                        2
# 530973               2             2              2                        2
# 553097               1             1              1                        1
# 556637               1             1              1                        1
# 557522               1             1              1                        1
# 566371               2             2              2                        2
# 570796               1             1              1                        1
# ...

# %%
df=df[df['SalePrice'] <= 530973]
sns.histplot(df['SalePrice'], bins=50, kde=True)
plt.show()

# %% [markdown]
# # **Model Buliding**

# %% [markdown]
# ## **Define X & y**

# %%
X = df.drop(columns='SalePrice')
X
# Out:
#      HallwayType TimeToSubway          SubwayStation  N_FacilitiesNearBy(ETC)  \
# 0       terraced       0-5min  Kyungbuk_uni_hospital                        0
# 1       terraced  10min-15min  Kyungbuk_uni_hospital                        1
# 2          mixed  15min-20min       Chil_sung_market                        1
# 3          mixed   5min-10min                Bangoge                        5
# 4       terraced       0-5min                Sin_nam                        0
# ...          ...          ...                    ...                      ...
# 4116    terraced       0-5min                Sin_nam                        0
# 4117       mixed  15min-20min              Myung_duk                        5
# 4118    terraced       0-5min                Sin_nam                        0
# 4119       mixed  15min-20min              Myung_duk                        5
# 4121    corridor   5min-10min                  Daegu                        2
#
# ...

# %%
y = df['SalePrice']
y
# Out:
# 0       346017
# 1       150442
# 2        61946
# 3       165486
# 4       311504
#          ...
# 4116    290265
# 4117    345132
# 4118    323008
# 4119    242477
# 4121     73451
# Name: SalePrice, Length: 2662, dtype: int64

# %% [markdown]
# ## **Data Splitting (Train Set, Test Set)**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %% [markdown]
# ## **Encoding**

# %% [markdown]
# - Encoding :
#     - Onehot: 'HallwayType',
#     - Binary: 'SubwayStation'
#     - ordinal: 'TimeToSubway'
# - Scaling:
#     - Robust: 'N_Parkinglot(Basement)','Size(sqf)'
#     - Standar: 'N_FacilitiesNearBy(ETC)', 'N_FacilitiesNearBy(PublicOffice)', 'N_SchoolNearBy(University)', 'N_FacilitiesInApt'

# %%
ordinal_mapping = {
    'col': 'TimeToSubway',
    'mapping': {
        'no_bus_stop_nearby': 0,
        '0-5min': 1,
        '5-10min': 2,
        '10-15min': 3,
        '15-20min': 4
    }}

# %%
pipe_ordinal = Pipeline(
    ('ordinal', OrdinalEncoder(mapping=[ordinal_mapping])))

# %%
transformer = ColumnTransformer([
    ('ordinal', OrdinalEncoder(mapping=[ordinal_mapping]), ['TimeToSubway']),
    ('onehot', OneHotEncoder(drop='first'), ['HallwayType']),
    ('binary', BinaryEncoder(), ['SubwayStation']),
    ('robust', RobustScaler(), ['N_Parkinglot(Basement)', 'Size(sqf)']),
    ('standard', StandardScaler(), ['N_FacilitiesNearBy(ETC)', 'N_FacilitiesNearBy(PublicOffice)', 'N_SchoolNearBy(University)', 'N_FacilitiesInApt', 'YearBuilt']),
])

# %%
transformer
# Out:
# ColumnTransformer(transformers=[('ordinal',
#                                  OrdinalEncoder(mapping=[{'col': 'TimeToSubway',
#                                                           'data_type': dtype('O'),
#                                                           'mapping': no_bus_stop_nearby    0
# 0-5min                1
# 5-10min               2
# 10-15min              3
# 15-20min              4
# dtype: int64}]),
#                                  ['TimeToSubway']),
#                                 ('onehot', OneHotEncoder(drop='first'),
#                                  ['HallwayType']),
#                                 ('binary', BinaryEncoder(), ['SubwayStation']),
#                                 ('robust', RobustScaler(),
#                                  ['N_Parkinglot(Basement)', 'Size(sqf)']),
#                                 ('standard', StandardScaler(),
#                                  ['N_FacilitiesNearBy(ETC)',
# ...

# %% [markdown]
# ## **Cross Validation**

# %%
# define algorithm
linear = LinearRegression()
tree = DecisionTreeRegressor(random_state=0)
knn = KNeighborsRegressor()
rf = RandomForestRegressor(random_state=0)
xgb = XGBRegressor(random_state=0)

# %%
list_model = [linear, tree, knn, xgb, rf]
scorer = ['neg_mean_absolute_error', 
          'neg_root_mean_squared_error', 
          'neg_mean_absolute_percentage_error',
          'r2'
]

# Pemodelan dilakukan dalam skala logaritmik, namun kemudian di-inverse kembali untuk interpretasi
log_lienar = TransformedTargetRegressor(linear, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_tree = TransformedTargetRegressor(tree, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)


# score r2
list_score_mean_r2 = []
list_score_std_r2 = []

# score rmse
list_score_mean_rmse = []
list_score_std_rmse = []

# score mae
list_score_mean_mae = []
list_score_std_mae = []

# score mape
list_score_mean_mape = []
list_score_std_mape = []

for model in list_model:
    # define pipe_model
    pipe_model = Pipeline([
        ('transformer', transformer),
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    # define cross validation
    cv_score = cross_validate(
        estimator=pipe_model,
        X=X_train,
        y=y_train,
        cv=5,
        scoring=scorer,
        error_score='raise',
    )
    # scoring r2
    list_score_mean_r2.append(cv_score["test_r2"].mean())
    list_score_std_r2.append(cv_score["test_r2"].std())

    # scoring rmse
    list_score_mean_rmse.append(cv_score["test_neg_root_mean_squared_error"].mean())
    list_score_std_rmse.append(cv_score["test_neg_root_mean_squared_error"].std())

    # scoring mae
    list_score_mean_mae.append(cv_score["test_neg_mean_absolute_error"].mean())
    list_score_std_mae.append(cv_score["test_neg_mean_absolute_error"].std())

    # scoring mape
    list_score_mean_mape.append(cv_score["test_neg_mean_absolute_percentage_error"].mean())
    list_score_std_mape.append(cv_score["test_neg_mean_absolute_percentage_error"].std())

# create dataframe
df_cv = pd.DataFrame()
df_cv["model"] = list_model
df_cv["mean_r2"] = list_score_mean_r2
df_cv["std_r2"] = list_score_std_r2
df_cv["mean_rmse"] = list_score_mean_rmse
df_cv["std_rmse"] = list_score_std_rmse
df_cv["mean_mae"] = list_score_mean_mae
df_cv["std_mae"] = list_score_std_mae
df_cv["mean_mape"] = list_score_mean_mape
df_cv["std_mape"] = list_score_std_mape
df_cv.sort_values(by='mean_r2', ascending=False, inplace=True)
df_cv
# Out:
#                                                model   mean_r2    std_r2  \
# 3  XGBRegressor(base_score=None, booster=None, ca...  0.806279  0.014950
# 4              RandomForestRegressor(random_state=0)  0.805310  0.014143
# 1              DecisionTreeRegressor(random_state=0)  0.805018  0.014877
# 2                              KNeighborsRegressor()  0.780339  0.017251
# 0                                 LinearRegression()  0.759704  0.012950
#
#       mean_rmse     std_rmse      mean_mae     std_mae  mean_mape  std_mape
# 3 -45794.956250   813.919671 -36988.698438  775.608074  -0.189546  0.003207
# 4 -45914.805439   703.969484 -37077.948790  743.530161  -0.190554  0.003087
# 1 -45945.554482   877.641180 -37044.907667  756.737967  -0.190228  0.003966
# 2 -48763.021718  1016.218351 -38667.831499  958.641782  -0.198657  0.006525
# 0 -51037.560980   771.610252 -41778.943453  767.059553  -0.216548  0.003540

# %% [markdown]
# Terdapat perbedaan yang cukup signifikan dari nilai MAE dan RMSE hal ini dikarenakan pada RMSE nilai residual errornya dikuadratkan terlebih dahulu sebelum dirata-ratakan.
#
# Berdasarkan data diatas maka diperoleh hasil bahwa model terbaik yang dapat digunakan yaitu **XGBRegressor** karena dari segi R2 menempati score yang tertinggi, menandakan bahwa lebih mampu menjelaskan variasi harga apartment. Kemudian model ini juga memiliki nilai RMSE, MAE, dan MAPE yang paling rendah diantara model lainnya.

# %% [markdown]
# ## **Hyperparameter Tuning**

# %% [markdown]
# ### **Before Tuning**

# %%
# Hyperparameter tuning model terbaik
models = {
    'XGB': XGBRegressor(random_state=0)
}
score_r2 = []
score_rmse = []
score_mae = []
score_mape = []

# Prediksi pada test set
for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', StandardScaler()),
        ('model', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_r2.append(r2_score(y_test, y_pred))
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'R2':score_r2,'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape}, index=models.keys())
score_before_tuning
# Out:
#            R2          RMSE          MAE      MAPE
# XGB  0.800891  46309.789548  37546.84375  0.193423

# %%
# Kedalaman pohon
max_depth = list(np.arange(1, 11))

# Learning rate
learning_rate = list(np.arange(1, 100)/100)

# Jumlah pohon
n_estimators = list(np.arange(100, 201))

# Jumlah baris tiap pohon (% dari total baris train set)
subsample = list(np.arange(2, 10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(1, 11)) # Semakin besar nilainya, semakin konservatif/simpel modelnya

# Jumlah feature yang digunakan untuk tiap pohon (% dari total kolom train set)
colsample_bytree = list(np.arange(1, 10)/10)

# Alpha (regularization)
reg_alpha = list(np.logspace(-3, 1, 10)) # Semakin besar nilainya, semakin konservatif/simpel modelnya


# Hyperparam space XGboost
hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# %%
# Model terpilih dengan hyperparameter tuning
xgb = XGBRegressor(random_state=0, verbosity=0)

# scorer
scorer = ['neg_mean_absolute_error', 
          'neg_root_mean_squared_error', 
          'neg_mean_absolute_percentage_error',
          'r2'
]

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('scaler', StandardScaler()),
        ('model', xgb)
        ])


# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 1000,
    cv = 5, 
    scoring = scorer,
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error', # Hanya bisa memilih salah stau metric untuk optimisasi
    random_state = 0  
)

# %%
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(transformers=[('ordinal',
#                                                                                OrdinalEncoder(mapping=[{'col': 'TimeToSubway',
#                                                                                                         'data_type': dtype('O'),
#                                                                                                         'mapping': no_bus_stop_nearby    0
# 0-5min                1
# 5-10min               2
# 10-15min              3
# 15-20min              4
# dtype: int64}]),
#                                                                                ['TimeToSubway']),
#                                                                               ('onehot',
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 241       0.275504      0.132100         0.060003        0.017752
# 69        0.202809      0.011046         0.039170        0.007505
# 697       0.161465      0.013948         0.032340        0.002367
# 894       0.167385      0.012504         0.036717        0.003970
# 480       0.252753      0.052488         0.038265        0.005743
#
#      param_model__subsample  param_model__reg_alpha  \
# 241                     0.8                0.166810
# 69                      0.7                0.464159
# 697                     0.9                0.002783
# 894                     0.9                0.059948
# 480                     0.6                0.021544
#
#      param_model__n_estimators  param_model__max_depth  \
# 241                        139                       3
# 69                         157                       4
# 697                        168                       3
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -45423.21015625
# Best_params: {'model__subsample': np.float64(0.8), 'model__reg_alpha': np.float64(0.1668100537200059), 'model__n_estimators': np.int64(139), 'model__max_depth': np.int64(3), 'model__learning_rate': np.float64(0.13), 'model__gamma': np.int64(9), 'model__colsample_bytree': np.float64(0.6)}

# %% [markdown]
# ### **After Tuning**

# %%
# Model XGBoost
model = {'XGB': XGBRegressor(random_state=0)}

# Define model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Fitting model
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
r2_xgb_tuning = r2_score(y_test, y_pred_xgb_tuning)
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)
mape_xgb_tuning = mean_absolute_percentage_error(y_test, y_pred_xgb_tuning)

score_after_tuning = pd.DataFrame({'R2':r2_xgb_tuning,'RMSE': rmse_xgb_tuning, 'MAE': mae_xgb_tuning, 'MAPE': mape_xgb_tuning}, index=model.keys())
score_after_tuning
# Out:
#            R2         RMSE           MAE      MAPE
# XGB  0.801797  46204.29348  37392.941406  0.192803

# %% [markdown]
# ### **Perbandingan Performa (Before Tuning & After Tuning)**

# %%
# Sebelum hyperparameter tuning
pd.DataFrame(score_before_tuning.loc['XGB']).T
# Out:
#            R2          RMSE          MAE      MAPE
# XGB  0.800891  46309.789548  37546.84375  0.193423

# %%
# Setelah hyperparameter tuning
score_after_tuning
# Out:
#            R2         RMSE           MAE      MAPE
# XGB  0.801797  46204.29348  37392.941406  0.192803

# %% [markdown]
# Setelah dilakukan tuning, model mengalami peningkatan performa yaitu ditandai dengan peningkatan nilai R2 dan penurunan pada nilai RMSE, MAE, dan MAPE. Walaupun peningkatan performa hanya sedikit, namun melakukan tuning pada model tetap disarankan.
# - Before Tuning :
#     - R2 : 0.800891
#     - RMSE : 46309.789062
#     - MAE : 37546.84375
#     - MAPE : 0.193423
#
# - After Tuning :
#     - R2 : 0.801797
#     - RMSE : 46204.292969
#     - MAE : 37392.941406
#     - MAPE : 0.192803

# %%
plt.figure(figsize=(14, 8))
plot = sns.scatterplot(x=y_test, y=y_pred_xgb_tuning).set(title='Actual vs. Prediction Price', 
                                               xlabel='Actual Price', 
                                               ylabel='Predicted Price')

# %% [markdown]
# **Interpretasi Hasil Model Prediksi**
#
# 1. Titik-titik pada plot tersebar disekitar garis diagonal (y=x) yang menunjukkan bahwa model secara keseluruhan mampu memprediksi harga dengan cukup baik. Terdapat tren positif dimana semakin tinggi harga aktual, semakin tinggi pula harga prediksi. Hal ini juga mengindikasikan bahwa model berhasil menangkap pola umum dalam data yaitu korelasi positif antara harga aktual dan prediksi.
#
# 2. Untuk harga yang lebih rendah (sekitar 50,000–200,000), titik-titik cenderung lebih dekat ke garis diagonal, menunjukkan prediksi yang lebih akurat untuk apartemen dengan harga terjangkau. Untuk harga yang lebih tinggi (di atas 300,000), ada sedikit penyimpangan , yang mengindikasikan bahwa model mungkin memiliki sedikit kesulitan dalam memprediksi harga apartemen premium dengan presisi yang sama. Nilai MAPE sebesar 0,192, meunjukkan bahwa tingkat kesalahan dalam melakukan prediksi sebesar 19,2%. Artinya prediksi harga apartemen dalam model ini menyimpang sebesar 19,2% dari harga aktual.
#
# 3. Beberapa titik terlihat menggumpal di bawah garis diagonal , terutama di rentang harga 200,000–300,000. Ini menunjukkan bahwa model cenderung underpredicting harga di rentang ini.
# Sebaliknya, ada beberapa titik yang menggumpal di atas garis diagonal , terutama di rentang harga 300,000–400,000. Ini menunjukkan bahwa model cenderung overpredicting harga di rentang ini.
#
# 4. Residuals (selisih antara harga aktual dan prediksi) tampaknya menyebar secara acak di sekitar garis diagonal, tanpa pola tertentu. Ini adalah tanda baik karena menunjukkan bahwa error tidak sistematis .
# Namun, ada cluster tertentu di mana residuals lebih besar, terutama di rentang harga 200,000–400,000.
#
# 5. Model tampaknya bekerja dengan baik untuk harga-harga moderat hingga tinggi , tetapi mungkin perlu penyesuaian lebih lanjut untuk meningkatkan akurasi pada rentang harga tertentu (misalnya, 200,000–300,000).
# Tidak ada indikasi kuat tentang bias signifikan atau varians residual yang tidak konstan (heteroskedastisitas).
#
# 6. Underprediction di rentang 200,000–300,000 : Mungkin disebabkan oleh kurangnya fitur penting yang relevan untuk menjelaskan variasi harga di rentang ini, atau model belum sepenuhnya menangkap pola kompleks di rentang tersebut.
# Overprediction di rentang 300,000–400,000 : Bisa jadi model memberikan bobot yang terlalu tinggi pada fitur tertentu (misalnya, fasilitas tambahan atau lokasi strategis) yang membuat prediksi menjadi terlalu tinggi.

# %%
# Plot feature importances
feature_names = transformer.get_feature_names_out()
feature_imp = pd.Series(xgb_tuning['model'].feature_importances_, index=feature_names).sort_values(ascending=False)
feature_imp.to_frame(name='Feature Importances')
# Out:
#                                             Feature Importances
# onehot__HallwayType_terraced                           0.647291
# ordinal__TimeToSubway                                  0.075871
# standard__YearBuilt                                    0.066529
# robust__Size(sqf)                                      0.055902
# standard__N_FacilitiesInApt                            0.041683
# standard__N_FacilitiesNearBy(ETC)                      0.034234
# robust__N_Parkinglot(Basement)                         0.028085
# standard__N_FacilitiesNearBy(PublicOffice)             0.016661
# standard__N_SchoolNearBy(University)                   0.011708
# binary__SubwayStation_1                                0.008337
# onehot__HallwayType_mixed                              0.007117
# binary__SubwayStation_0                                0.003590
# binary__SubwayStation_2                                0.001659
# binary__SubwayStation_3                                0.001332

# %%
feature_imp = pd.Series(xgb_tuning['model'].feature_importances_, index=feature_names).sort_values(ascending=False).head()
feature_imp.plot(kind='barh', title='Feature Importances')
# Out:
# <Axes: title={'center': 'Feature Importances'}>

# %% [markdown]
# **Feature Importances**
#
# 1. Fitur Terpenting: onehot__Hallwaytype_terraced memiliki nilai penting tertinggi (~0.65). Ini menunjukkan bahwa tipe hallway menjadi faktor paling signifikan dalam penentuan harga properti.
#
# 2. Waktu ke stasiun kereta terdekat: ordinal__TimeToSubway memiliki pengaruh sebesar (~0.08), perkiraan waktu ke stasiun terdekat menjadi salah satu faktor dalam penentuan harga.
#
# 3. Tahun dibangun : standard__YearBuilt memiliki pengaruh sebesar (~0.07) menunjukkan tahun dibangunnya apartment menjadi salah satu faktor utama dalam penentuan harga properti.
#
# 4. Ukuran apartment: robust__Size(sqf) (~0.06) menunjukkan bahwa jumlah ukuran apartment menjadi salahsatu faktor penentuan harga properti.
#
# 5. Fitur terrendah: standard__N_FacilitiesInApt memiliki nilai penting terendah (~0.04), menandakan dampaknya lebih kecil dibandingkan fitur lainnya.

# %% [markdown]
# # **Conclusion**
#
# Berdasarkan model prediksi yang telah dilakukan didapatkan hasil bahwa fitur HallwayType merupakan fitur yang memiliki pengaruh terbesar terhadap penentuan harga dari semua fitur. Model memiliki performa yang cukup baik dalam memprediksi harga apartemen, terutama untuk harga yang lebih rendah.
#
# Matriks evaluasi yang digunakan dalam model ini adalah R2, RMSE, MAE dan MAPE. Jika melihat dari MAPE setelah dilakukan hyperparameter tuning diperoleh hasil bahwa model yang telah dibuat memiliki kesalahan/penyimpangan harga prediksi dari harga aktual sebesar 19,2%. Dengan kata lain jika harga apartment 585840 Won, maka perkiraan harganya akan meleset sebesar 19,2% dari harga aktualnya. Namun tidak menutup kemungkinan bahwa prediksinya juga bisa meleset lebih jauh,  hal ini dapat disebabkan oleh bias dalam dataset terutama oleh fitur-fitur yang kurang mempresentasikan pengaruhnya terhadap penentuan harga apartment. Secara keseluruhan, model telah menangkap tren utama, tetapi masih ada ruang untuk peningkatan khususnya dalam menangani variasi harga di rentang tertentu.

# %% [markdown]
# # **Recommendations**

# %% [markdown]
# 1. Feature Engineering :
#
#     Tambahkan fitur baru yang relevan, seperti jumlah lantai , tingkat kerapatan populasi di sekitar apartemen , atau tingkat inflasi daerah. Buat interaksi antar fitur jika ada hubungan non-linear yang mungkin terlewatkan.
#
# 2. Hyperparameter Tuning :
#
#     Lakukan Grid Search atau Random Search untuk mencari kombinasi hyperparameter yang optimal. Coba algoritma lain seperti Gradient Boosting Machines (XGBoost, LightGBM) atau Neural Networks jika model saat ini masih memiliki error yang signifikan.
#
# 3. Lakukan Pemeriksaan Eror Pada Prediksi:
#
#     Lakukan pemeriksaan pada prediksi untuk mengetahui prediksi mana yang memilik eror yang tinggi. Setelahnya kita bisa mengecek hubungan antara error tersebut dengan tiap variabel independen. Pada akhirnya kita dapat mengetahui sebenarnya variabel mana saja dan aspek apa yang menyebabkan model menghasilkan error yang tinggi, sehingga kita bisa melakukan training ulang dengan penerapan feature engineering lainnya.
#
# 4. Model yang sudah dibangun ini bisa dimanfaatkan untuk pengembangan pembuatan model lainnya. Contohnya seperti pembuatan model untuk memprediksi mobil bekas, atau harga sewa kamar hotel.

# %% [markdown]
# ## **Save Model**

# %%
# Save Model
import pickle

predictor = Pipeline([('preprocess', transformer), ('model', XGBRegressor())])
predictor.fit(X_train, y_train)

pickle.dump(predictor, open('Daegu_Apartment_XGB.sav', 'wb'))

# %%
# Load Model
filename = 'Daegu_Apartment_XGB.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# np.float64(46309.7895482154)
